# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'

# %%
models = {}
for  i, day in enumerate(['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']):
    with open('weights/{}_3.0.pickle'.format(day), 'rb') as file:
        models[day] = pickle.load(file)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

n = 10
fig, ax = plt.subplots(2, 4, figsize=(16, 7))
for i, day in enumerate(['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']):
    ax.flatten()[i].plot(models[day].history['rewards'], label='episode rewards', color='green')
    moving_loss = np.convolve(models[day].history['rewards'], np.ones((n,))/n, mode='valid')
    ax.flatten()[i].plot(moving_loss, label='moving rewards', color='orange')
plt.legend()
ax.flatten()[-1].remove()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(10, 7))
n = 24
ax.plot(model.history['batch_loss'], label='batch loss')
moving_loss = np.convolve(model.history['batch_loss'], np.ones((n,))/n, mode='valid')
ax.plot(moving_loss, label='moving loss', color='orange')
plt.legend()
